# %% [markdown]
# <a href="https://colab.research.google.com/github/flatplanet/Data_Analysis_With_Python_Course/blob/main/Matplotlib_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib - Charts and Graphs

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# %%
# Create Random Number DataFrame
my_df = pd.DataFrame(randn(20, 4), columns=["Mon", "Tues", "Wed", "Thur"])
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0  -1.354423  0.525363  0.272923  0.389070
# 1   0.238990  0.391700  0.372399 -0.836645
# 2  -0.039098  1.388847  0.967990 -0.412578
# 3  -0.775108 -0.216057 -0.608975 -1.238033
# 4  -0.065655 -0.633326  0.018271  0.254833
# 5  -0.862203 -1.017930  0.257380 -0.982682
# 6   0.824465 -0.287832  0.038557  0.614150
# 7  -0.777652  0.850396  1.102511  0.141737
# 8   0.841836 -0.795239  0.259668 -2.990799
# 9  -0.082258  0.421794 -0.983670  0.845948
# 10  0.728919 -2.023246 -1.044809  1.837319
# 11 -0.106145  0.638539 -0.214554 -0.745353
# 12  0.186141  1.440186 -0.873199 -0.718910
# 13 -1.610816  0.011732 -0.648938 -0.343723
# 14  0.383304  0.271206  0.474018 -0.763779
# 15 -0.351800  0.294944  1.211982 -0.445690
# 16  0.666652 -0.893819 -0.658319 -0.427641
# 17  2.017041 -1.444231  0.224561 -0.488426
# 18 -0.707196  0.870067  0.001645 -0.393393
# 19  0.624234  0.999096 -0.566417  0.823227

# %%
# Bar Chart
my_df.abs().plot(kind="bar")
# Out:
# <Axes: >

# %%
# Bar Chart Stacked
my_df.abs().plot(kind="bar", stacked=True)
# Out:
# <Axes: >

# %%
# Grid Lines
my_df.abs().plot(kind="bar", stacked=True, grid=True)
# Out:
# <Axes: >

# %%
# Shading
my_df.abs().plot(kind="bar", stacked=True, alpha=0.5)
# Out:
# <Axes: >

# %%
# Title
my_df.abs().plot(kind="bar", stacked=True, alpha=0.5, title="My awesome Barchart")
# Out:
# <Axes: title={'center': 'My awesome Barchart'}>

# %%
# Legend
my_df.abs().plot(kind="bar", stacked=True, alpha=0.5, legend=False)
# Out:
# <Axes: >

# %%
# Second Way
my_df.abs().plot.bar()
# Out:
# <Axes: >

# %%
# Second Way Stacked
my_df.abs().plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
# Second Way Shading
my_df.abs().plot.bar(stacked=True, alpha=0.5)
# Out:
# <Axes: >

# %%
# Second Way Title
my_df.abs().plot.bar(stacked=True, alpha=0.5, title="My 2nd BarChart")
# Out:
# <Axes: title={'center': 'My 2nd BarChart'}>

# %%
# Second Way Legend
my_df.abs().plot.bar(stacked=True, alpha=0.5, legend=False)
# Out:
# <Axes: >

# %%
# Second Way Grid Lines
my_df.abs().plot.bar(stacked=True, alpha=0.5, grid=True)
# Out:
# <Axes: >

# %%
# Line Charts
my_df.abs().plot(kind="line")
# Out:
# <Axes: >

# %%
# Line Width
my_df.abs().plot(kind="line", lw=3)
# Out:
# <Axes: >

# %%
# Line Single
my_df["Mon"].abs().plot(kind="line")
# Out:
# <Axes: >

# %%
# Line more than one
my_df[["Mon", "Tues"]].abs().plot(kind="line")
# Out:
# <Axes: >

# %%
# Size
my_df.abs().plot(kind="line", figsize=(10, 5))
# Out:
# <Axes: >

# %%
# Title
my_df.abs().plot(kind="line", title="My Not Awesome LineChart")
# Out:
# <Axes: title={'center': 'My Not Awesome LineChart'}>

# %%
# Shading
my_df.abs().plot(kind="line", alpha=0.6)
# Out:
# <Axes: >

# %%
# Legend
my_df.abs().plot(kind="line", legend=False)
# Out:
# <Axes: >

# %%
# Second Way Line Charts
my_df.abs().plot.line(lw=3)
# Out:
# <Axes: >

# %%
my_df = pd.DataFrame(randn(500, 4), columns=["Mon", "Tues", "Wed", "Thur"])  # Add more data
my_df
# Out:
#           Mon      Tues       Wed      Thur
# 0    0.614837 -0.153227 -0.499409  0.558220
# 1   -0.132614 -1.430715 -0.182928  0.420856
# 2   -0.889193  2.186383  0.696811 -1.210382
# 3    2.556776 -0.728981  0.076357  0.481481
# 4   -0.162471  1.337272 -0.714554  0.293935
# ..        ...       ...       ...       ...
# 495 -1.990830 -1.327221  0.491418 -2.406834
# 496  1.862896  0.837612  1.618093  0.048793
# 497  0.334442 -1.692119  1.385871  0.136433
# 498  0.160571 -1.542753  1.073736 -2.818952
# 499 -1.287629 -0.619524  2.223544 -0.271384
#
# [500 rows x 4 columns]

# %%
# Scatterplots
my_df.plot(kind="scatter", x="Mon", y="Tues")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Add third variable weight
my_df.plot(kind="scatter", x="Mon", y="Tues", c="Wed")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Add Colors   https://matplotlib.org/stable/users/explain/colors/colormaps.html
my_df.plot(kind="scatter", x="Mon", y="Tues", c="Wed", cmap="seismic")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# By Size
my_df.plot(kind="scatter", x="Mon", y="Tues", s=my_df["Wed"]*100, cmap="seismic")
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/collections.py:1008: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/core.py:1345: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# By Size easier to read with Alpha
my_df.plot(kind="scatter", x="Mon", y="Tues", s=my_df["Wed"]*100, cmap="seismic", alpha=0.3)
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/collections.py:1008: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/core.py:1345: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Title Etc
my_df.plot(kind="scatter", x="Mon", y="Tues", s=my_df["Wed"]*200, cmap="seismic", alpha=0.3, title="My Groovy Scatterplot", legend=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/collections.py:1008: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/core.py:1345: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: title={'center': 'My Groovy Scatterplot'}, xlabel='Mon', ylabel='Tues'>

# %%
# Boxplots
my_df.plot(kind="box")
# Out:
# <Axes: >

# %%
# Size
my_df.plot(kind="box", figsize=(10,5))
# Out:
# <Axes: >

# %%
# Boxplot Color
my_df.plot(kind="box", figsize=(10,5), cmap="bwr")
# Out:
# <Axes: >

# %%
# No Legend
my_df.plot(kind="box", figsize=(10,5), cmap="bwr", legend=True)
# Out:
# <Axes: >

# %%
# Grid
my_df.plot(kind="box", figsize=(10,5), cmap="bwr", grid=True)
# Out:
# <Axes: >

# %%
# Title stuff
my_df.plot(kind="box", figsize=(10,5), cmap="bwr", title="Whiskers!")
# Out:
# <Axes: title={'center': 'Whiskers!'}>

# %%
# Other Way
my_df.plot.box()
# Out:
# <Axes: >

# %%
# Hexplots
my_df.plot(kind="hexbin", x="Mon", y="Tues")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Gridsize
my_df.plot(kind="hexbin", x="Mon", y="Tues", gridsize=10)
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# C
my_df.plot(kind="hexbin", x="Mon", y="Tues", C="Wed", gridsize=10)
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Color
my_df.plot(kind="hexbin", x="Mon", y="Tues", gridsize=10, cmap="jet")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Grid
my_df.plot(kind="hexbin", x="Mon", y="Tues", gridsize=10, grid=True)
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Title
my_df.plot(kind="hexbin", x="Mon", y="Tues", gridsize=10, title="My Hexy!")
# Out:
# <Axes: title={'center': 'My Hexy!'}, xlabel='Mon', ylabel='Tues'>

# %%
# Other Method
my_df.plot.hexbin(x="Mon", y="Thur", gridsize=10)
# Out:
# <Axes: xlabel='Mon', ylabel='Thur'>

# %%
# Density and KDE Plots (Kernal Density Plots)
my_df.plot(kind="kde", alpha=0.3, grid=True)
# Out:
# <Axes: ylabel='Density'>

# %%
# Second way
my_df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
# Density Plot
my_df.plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
# Second way
my_df.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
# Tile Grid etc
my_df.plot.density(title="Terrible Densities", legend=True)
# Out:
# <Axes: title={'center': 'Terrible Densities'}, ylabel='Density'>
