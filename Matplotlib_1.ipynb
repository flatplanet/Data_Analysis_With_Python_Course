# %% [markdown]
# <a href="https://colab.research.google.com/github/flatplanet/Data_Analysis_With_Python_Course/blob/main/Matplotlib_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Charts and Graphs with Matplotlib

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# %%
# Create Random Number DataFrame
my_df = pd.DataFrame(randn(100, 4), columns=["Mon", "Tues", "Wed", "Thur"])
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0   2.137579 -1.310213 -0.260757 -1.490207
# 1  -0.418823  1.897335 -0.234412 -0.345535
# 2   0.857799  2.692916 -0.927649 -1.026842
# 3   0.472667  1.222306  0.262899  0.832915
# 4  -0.662608 -0.248306 -1.022934 -1.771253
# ..       ...       ...       ...       ...
# 95  0.655030 -0.486146  0.445959  1.712941
# 96 -0.916615 -1.159516  1.361722 -1.236977
# 97  1.578624  0.075206  0.481224  0.751267
# 98  0.759293 -1.405359 -2.092189  1.477110
# 99  1.486858  0.982304 -0.077276 -0.182248
#
# [100 rows x 4 columns]

# %%
# Histogram
my_df["Wed"].hist()
# Out:
# <Axes: >

# %%
# Histogram with smaller bins, 50, 20
my_df["Wed"].hist(bins=20)
# Out:
# <Axes: >

# %%
# Second Method to create Histograms
my_df["Wed"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Original method without gridlines
my_df["Wed"].hist(bins=20, grid=False)
# Out:
# <Axes: >

# %%
# Add a Legend
my_df["Wed"].hist(bins=20, grid=False, legend=True)
# Out:
# <Axes: >

# %%
# Area Plots
# Create Random Number DataFrame
my_df = pd.DataFrame(randn(20, 4), columns=["Mon", "Tues", "Wed", "Thur"])
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0   0.271184  0.606111  1.141343  0.269691
# 1  -0.440016  0.099525  0.067399  0.685265
# 2  -0.432588 -0.108643  0.575854 -0.673631
# 3  -1.458011 -1.055719  0.210275  0.132594
# 4   0.866962  0.987858 -1.325934  1.796056
# 5  -1.011128 -0.643679 -0.822030  0.004072
# 6   0.304335  0.189106  0.735402 -0.756030
# 7  -0.025650  1.698262 -1.332126 -0.596153
# 8   0.764020  1.308379  0.619326  2.025762
# 9   0.948914  1.260395  0.985511  0.843522
# 10 -0.345281  0.952502 -0.102381  0.513815
# 11  0.331986  1.718396  1.071840 -0.511966
# 12 -0.230018  0.185211 -0.359548 -1.103320
# 13 -1.191220 -0.104351 -0.777042 -1.948897
# 14  0.437902 -1.570274 -1.817445  0.254525
# 15 -1.283163 -0.497518  0.573446  0.118529
# 16  0.691079  0.672189 -0.290946 -0.534027
# 17 -0.664186 -1.107903 -0.094965  1.071893
# 18  1.226148  0.588437  0.855479 -1.133924
# 19 -1.004750 -0.036424  0.496704  0.431532

# %%
# Create Area Plot
my_df.plot(kind="area", stacked=False)
# Out:
# <Axes: >

# %%
# Absolute Values
my_df.abs().plot(kind="area")
# Out:
# <Axes: >

# %%
# Shading
my_df.abs().plot(kind="area", alpha=0.3) # Closer to 0 is more transparent
# Out:
# <Axes: >

# %%
# Title
my_df.abs().plot(kind="area", alpha=0.3, title="My Very Cool Area Plot")
# Out:
# <Axes: title={'center': 'My Very Cool Area Plot'}>

# %%
# Remove Legend
my_df.abs().plot(kind="area", alpha=0.3, title="My Very Cool Area Plot", legend=False)
# Out:
# <Axes: title={'center': 'My Very Cool Area Plot'}>

# %%
# Plot only one column
my_df['Mon'].abs().plot(kind="area", alpha=0.3, title="My Very Cool Area Plot")
# Out:
# <Axes: title={'center': 'My Very Cool Area Plot'}>

# %%
# Plot 2 Columns
my_df[["Mon", "Wed"]].abs().plot(kind="area", alpha=0.3, title="My Very Cool Area Plot", legend=False)
# Out:
# <Axes: title={'center': 'My Very Cool Area Plot'}>

# %%
# Get info on a Function Shift Tab on the function - remove abs
my_df.plot(kind="area")

# %%
# Add Table
my_df.abs().plot(kind="area", alpha=0.3, title="My Very Cool Area Plot", legend=False, table=True)
# Out:
# <Axes: title={'center': 'My Very Cool Area Plot'}>
